# %%
import numpy as np
import pandas as pd
from snownlp import SnowNLP
import re

# %%
training_data_path = './data/training_data/Goods_Comments/pda'
test_data_paths = ['./data/test_data/0926.xlsx','./data/test_data/1017.xlsx','./data/test_data/1107.xlsx','./data/test_data/1114.xlsx','./data/test_data/1128.xlsx','./data/test_data/1205.xlsx','./data/test_data/1212.xlsx']

# %%
# 重新训练模型
sentiment.train('./neg.txt', './pos.txt')
# 保存好新训练的模型
sentiment.save('sentiment.marshal')

# %%
def read_and_adjust_sheet(test_data_path):
    # 只读取回帖列
    sheet = pd.read_excel(test_data_path, usecols=[2], header = None)
    sheet = sheet.drop([0])
    sheet = sheet.rename(columns={0: 'replies'})
    
    # 清理数据
    clean_reply = []
    for index,row in sheet.iterrows():
        reply = row.str.cat(sep=',')
        # reply = row[0]
        # 自动回复内容删除  
        auto = '(\s)*回复\s[0-9]*(\s)*#(\s)*的帖子(\n)*'
        reply = re.sub(auto,'',reply)
        clean_reply.append(reply)
    
    clean_replies = np.array(clean_reply)
    sheet.insert(0, 'clean_replies',clean_replies)
    
    # 删除字数小于15字的帖子
    for index,row in sheet.iterrows():
        clean_data = row['clean_replies']
        if(len(clean_data)<15):
            sheet = sheet.drop(index)
        
    return sheet

# %%
def predict_sentiment(classifier, sheet):
    sentiment = []
    for index,row in sheet.iterrows():
        sentiment.append(classifier.classify(row.str.cat(sep=',')))
    return sentiment

# %%
def extract_keywords(sheet):
    keywords = []
    for index,row in sheet.iterrows():
        #提取2个关键词
        extraction = list(HanLP.extractKeyword(row.str.cat(sep=','), 2))
        temp = ','.join(extraction)
        keywords.append(temp)
        #提取1个关键词
        #keywords.append(HanLP.extractKeyword(row.str.cat(sep=','), 1))
    return keywords

# %%
def write(keywords,sentiment,test_data_path):
    # 在表格中加入新列(结果列)
    sentiment_results = np.array(sentiment)
    keywords_results = np.array(keywords)
    sheet.insert(1, 'sentiment', sentiment_results)
    sheet.insert(1, 'keywords',keywords_results)
    
    # 设置写回路径
    root_path = './data/results_v2/'
    suffix = test_data_path[-9:-5]+'_output_v2.xlsx'
    back_path = root_path+suffix
    #print(back_path)
    sheet.to_excel(back_path)

# %%
if __name__ == '__main__':
    classifier = train_classifier(training_data_path)
    
    for test_data_path in test_data_paths:
        sheet = read_and_adjust_sheet(test_data_path)
        sentiment = predict_sentiment(classifier,sheet)
        keyword = extract_keywords(sheet)
        write(keyword,sentiment,test_data_path)

# %%
sheet
# Out:
#                                         clean_replies keywords sentiment  \
# 3          思维导图画的很仔细，小的知识点都涉及到了，而且还添加了一些图标，比较清楚，值得学习。    学习,值得        正面
# 4            谢谢你的意见，我们可以通过思维导图将知识点一层层的的串联起来，使其更具有整体性。     回复,#        负面
# 5                                活动二的几个任务都把每一个步骤具体化很好   具体化,活动        正面
# 6                       谢谢，其实思维导图我们只是细化了一下。细节方面还需要完善      #,其实        正面
# 7            很细致，但感觉可以精炼一些，比如概念内涵之类的，会让层次结构更加清晰。值得借鉴。    值得,更加        正面
# 8   你们的思维导图本身知识点划分细致，再贴图的话就显得繁琐、复杂，视觉效果不是很好。如果分支可以...   再,视觉效果        负面
# 9                  思维导图和数据分析都很不错，给我的感觉就是一张图解决了所有，特别详细     导,解决        正面
# 10                            思维导图内容很丰富，实验数据也很完整，值得借鉴    数据,值得        负面
# 12                         我们会考虑你的建议的，主要是想着贴图能够更加具体化    具体化,更加        负面
# 14       思维导图很详尽，分析的过程步骤很完整，只是有的结果分析，如果能够分析的更深入一点就好了。    分析,详尽        负面
# 16                               思维导图过于详细，是否再高度概括凝练一下    过于,详细        负面
# 18                                  谢谢你的提议，我们下次会注意的。     谢谢,帖子        负面
# 19         做的思维导图可以直接收起分支  图表是一些案例介绍 是为了让别人更加一目了然  谢谢    图表,更加        负面
# 21                                  思维导图很详尽，图文并茂，值得学习  图文并茂,值得        负面
# 22  思维导图的内容非常丰富，细节性的内容也全部都展示出来了，而且大多数采用图表，非常明晰明了，值得学习     内容,导        正面
# 23                                思维导图\n所用软件：Mindjet     思维,软件        负面
# 25            思维导图做的比较凝练，多因素方差的主效应分析的一样，是否需要研究两者的交叉效应    效应,分析        负面
# 26  任务完成十分细致，值得学习。思维导图制作的风格十分简洁明了，我不确定思维导图到底是应该做的细...     十分,导        负面
# 27                                    思维导图需要在线条方面加以改进  需要,加以改进        负面
# 28                                 思维导图让人一目了然，颜色分类都不错  颜色,一目了然        正面
# 29              思维导图清晰干净，但前几章很多重复后几章又很简洁，感觉可以做的再细致一点？    重复,细致        负面
# 30                               思维导图做的非常好，层层递进，简洁明了   帖子,简洁明了        负面
# 31  是的，我认为在进行多因素方差分析时除了主效应分析，也是需要交互效应分析的，这是我们组做的不足...    效应,分析        负面
# 32                                思维导图很直观、简洁，数据分析也很全面    直观,全面        负面
# 33                                   思维导图是不是可以适当添加细节？    细节,适当        正面
# 34                          思维导图很有自己的特色，分析过程也很完整，值得学习    值得,分析        负面
# 37                           谢谢你的建议，我们会继续完善自己的思维导图设计的    谢谢,帖子        负面
# 38                  谢谢你的意见，我们会探索使用更多的思维导图软件，做到最好的呈现方式     #,呈现        负面
# 39                      思维导图逻辑清晰，但是可以更详细一点，感觉文字描述较抽象。     更,详细        负面
# 42                      思维导图结构清晰，内容简洁，但是对于细节的展示可能有些缺少    可能,细节        负面
# ..                                                ...      ...       ...
# 51                            思维导图独具特色，色彩、线条分明，清晰逻辑性强    清晰,分明        负面
# 52  展示的方式最好还是统一下，要么都是图片要么都在一个文档里面，这样找起来着实不方便。数据分析部...   图片,不方便        负面
# 53                         思维导图很简洁、清晰，数据分析步奏也很完整，逻辑清晰  清晰,数据分析        负面
# 54  主要是免费软件只能导出图片，导出PDF需要付费，清晰度确实有点不够。现在这个图片是插入到WO...    图片,导出        负面
# 55                                 通过不同颜色区分分支，不同部分很明确    颜色,分支        负面
# 57  从大家的评论来看，大部分人还是不会下载附件来看的，贴图是为了方便大家浏览，至少是贴出了思维导...     评论,图        负面
# 58                                思维导图运用了不同的颜色，部分划分清晰    不同,颜色        负面
# 59                                 思路清晰，将重点部分标注出来，非常好    非常,清晰        负面
# 60                        思维导图逻辑清晰，但是可以更详细一点，文字描述较抽象。     更,详细        负面
# 61                               思维导图的色彩搭配有些乱 看起来不太舒服     色彩,乱        负面
# 62                     谢谢你的肯定，我们也是针对上节课汇报时大家的建议进行改进的     帖子,进行        负面
# 63                我们主要是理清要点，提供一个“导”的思路，而不是把所有的内容都添加进来    理清,帖子        负面
# 64                       谢谢你的建议，本来想直接输上去的，但是没办法，然后截图了      #,没        负面
# 65                    思维导图做的很好，简洁清晰，同意楼上的观点，这个颜色可以改一下    颜色,楼上        负面
# 66               思维导图的内容简明扼要，但是如果对于一些细节的内容可以选择性观看就更好了     导,观看        正面
# 67               思维导图【所有后面带有蓝色气泡的短语都能点击查看备注（详细内容解释等）】    蓝色,气泡        负面
# 68      分析任务完成的很细致，如果后面几个任务能像任务二一样贴上操作的步骤的详细叙述的话将会更好。    任务,分析        负面
# 69                                   谢谢评价我们会认真考虑你的建议     谢谢,帖子        负面
# 70        导图做的不错，建议可以第一级子标题加上序号，1,2,3,4,5好让人知道学习顺序与逻辑    学习,加上        正面
# 71                   谢谢，前面有加但是后面时间仓促没来得及补完，后期会继续完善的。       没,加        负面
# 72                  思维导图做的很好，任务有些太简洁，有些只是截图，缺乏必要的文字说明  文字说明,必要        正面
# 73                 数据分析任务有的详细，有的简略，最好都详细一点哦，体现一下操作思路     详细,操作        负面
# 74                             谢谢你的建议，我们会考虑再加上些文字描述的     帖子,加上        负面
# 75                    图文并茂很清晰，但有些图片并不能看得清楚内容，可以选择不放上去  选择,图文并茂        负面
# 77                  对于任务三 非参数检验，和其他组做的都不太一样，可能存在一点问题。     组,可能        负面
# 78                                思维导图中使用图文结合，很好，清晰明了    图文,使用        正面
# 79                             思维导图部分很全面，看着也色彩明快，值得肯定    值得,全面        负面
# 80                        思维导图逻辑清晰，但是可以更详细一点，文字描述较抽象。     更,详细        负面
# 83             我们这里的非参数检验，检验条件为：是否满足正态分布，所以和其他同学的不一样。  帖子,其他同学        负面
# 84             恩恩，我们当初的想法是把思维导图做的详细，因此可能内容涉及的多，字就显小了。      恩,导        负面
#
#                                               replies
# 3          思维导图画的很仔细，小的知识点都涉及到了，而且还添加了一些图标，比较清楚，值得学习。
# 4   回复 4 # 的帖子谢谢你的意见，我们可以通过思维导图将知识点一层层的的串联起来，使其更具有...
# 5                                活动二的几个任务都把每一个步骤具体化很好
# 6           回复 6 # 的帖子\n谢谢，其实思维导图我们只是细化了一下。细节方面还需要完善
# 7            很细致，但感觉可以精炼一些，比如概念内涵之类的，会让层次结构更加清晰。值得借鉴。
# 8   你们的思维导图本身知识点划分细致，再贴图的话就显得繁琐、复杂，视觉效果不是很好。如果分支可以...
# 9                  思维导图和数据分析都很不错，给我的感觉就是一张图解决了所有，特别详细
# 10                            思维导图内容很丰富，实验数据也很完整，值得借鉴
# 12             回复 9 # 的帖子\n我们会考虑你的建议的，主要是想着贴图能够更加具体化
# 14       思维导图很详尽，分析的过程步骤很完整，只是有的结果分析，如果能够分析的更深入一点就好了。
# 16                               思维导图过于详细，是否再高度概括凝练一下
# 18                      回复 8 # 的帖子\n谢谢你的提议，我们下次会注意的。
# 19  回复 9 # 的帖子\n做的思维导图可以直接收起分支  图表是一些案例介绍 是为了让别人更加...
# 21                                  思维导图很详尽，图文并茂，值得学习
# 22  思维导图的内容非常丰富，细节性的内容也全部都展示出来了，而且大多数采用图表，非常明晰明了，值得学习
# 23                                思维导图\n所用软件：Mindjet
# 25            思维导图做的比较凝练，多因素方差的主效应分析的一样，是否需要研究两者的交叉效应
# 26  任务完成十分细致，值得学习。思维导图制作的风格十分简洁明了，我不确定思维导图到底是应该做的细...
# 27                                    思维导图需要在线条方面加以改进
# 28                                 思维导图让人一目了然，颜色分类都不错
# 29              思维导图清晰干净，但前几章很多重复后几章又很简洁，感觉可以做的再细致一点？
# 30                   回复 2 # 的帖子\n思维导图做的非常好，层层递进，简洁明了
# 31  回复 4 # 的帖子\n是的，我认为在进行多因素方差分析时除了主效应分析，也是需要交互效应分...
# 32                                思维导图很直观、简洁，数据分析也很全面
# 33                                   思维导图是不是可以适当添加细节？
# 34                          思维导图很有自己的特色，分析过程也很完整，值得学习
# 37               回复 8 # 的帖子\n谢谢你的建议，我们会继续完善自己的思维导图设计的
# 38      回复 6 # 的帖子\n谢谢你的意见，我们会探索使用更多的思维导图软件，做到最好的呈现方式
# 39                      思维导图逻辑清晰，但是可以更详细一点，感觉文字描述较抽象。
# 42                      思维导图结构清晰，内容简洁，但是对于细节的展示可能有些缺少
# ..                                                ...
# 51                            思维导图独具特色，色彩、线条分明，清晰逻辑性强
# 52  展示的方式最好还是统一下，要么都是图片要么都在一个文档里面，这样找起来着实不方便。数据分析部...
# 53                         思维导图很简洁、清晰，数据分析步奏也很完整，逻辑清晰
# 54  回复 7 # 的帖子\n主要是免费软件只能导出图片，导出PDF需要付费，清晰度确实有点不够。...
# 55                                 通过不同颜色区分分支，不同部分很明确
# 57  回复 11# 的帖子\n从大家的评论来看，大部分人还是不会下载附件来看的，贴图是为了方便大家...
# 58                                思维导图运用了不同的颜色，部分划分清晰
# 59                                 思路清晰，将重点部分标注出来，非常好
# 60                        思维导图逻辑清晰，但是可以更详细一点，文字描述较抽象。
# 61                               思维导图的色彩搭配有些乱 看起来不太舒服
# 62         回复 4 # 的帖子\n谢谢你的肯定，我们也是针对上节课汇报时大家的建议进行改进的
# 63    回复 5 # 的帖子\n我们主要是理清要点，提供一个“导”的思路，而不是把所有的内容都添加进来
# 64           回复 11# 的帖子\n谢谢你的建议，本来想直接输上去的，但是没办法，然后截图了
# 65                    思维导图做的很好，简洁清晰，同意楼上的观点，这个颜色可以改一下
# 66               思维导图的内容简明扼要，但是如果对于一些细节的内容可以选择性观看就更好了
# 67               思维导图【所有后面带有蓝色气泡的短语都能点击查看备注（详细内容解释等）】
# 68      分析任务完成的很细致，如果后面几个任务能像任务二一样贴上操作的步骤的详细叙述的话将会更好。
# 69                       回复 4 # 的帖子\n谢谢评价我们会认真考虑你的建议
# 70        导图做的不错，建议可以第一级子标题加上序号，1,2,3,4,5好让人知道学习顺序与逻辑
# 71       回复 6 # 的帖子\n谢谢，前面有加但是后面时间仓促没来得及补完，后期会继续完善的。
# 72                  思维导图做的很好，任务有些太简洁，有些只是截图，缺乏必要的文字说明
# 73     回复 2 # 的帖子\n数据分析任务有的详细，有的简略，最好都详细一点哦，体现一下操作思路
# 74                 回复 8 # 的帖子\n谢谢你的建议，我们会考虑再加上些文字描述的
# 75                    图文并茂很清晰，但有些图片并不能看得清楚内容，可以选择不放上去
# 77                  对于任务三 非参数检验，和其他组做的都不太一样，可能存在一点问题。
# 78                                思维导图中使用图文结合，很好，清晰明了
# 79                             思维导图部分很全面，看着也色彩明快，值得肯定
# 80                        思维导图逻辑清晰，但是可以更详细一点，文字描述较抽象。
# 83  回复 13# 的帖子\n我们这里的非参数检验，检验条件为：是否满足正态分布，所以和其他同学的...
# 84  回复 11# 的帖子\n恩恩，我们当初的想法是把思维导图做的详细，因此可能内容涉及的多，字就...
#
# [65 rows x 4 columns]
