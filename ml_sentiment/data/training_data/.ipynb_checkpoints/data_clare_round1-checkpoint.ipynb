# %%
import pandas as pd

# %%
excel_path = './douban_comments.xls'
sheet = pd.read_excel(excel_path, usecols=[0,3,4], header = None)
print(sheet)
# Out:
#            0  1                                                  2
# 0      39234  4               "本片根据真实事件改编"，白日焰火版老无所依。但比起同名美剧可看性不高。
# 1      40945  5                          "不能感觉到微风拂过脸庞，拥有一双翅膀又有什么用"
# 2      31936  5                     "查理,带我回家"---腹黑兄控美少年与天才忠犬攻州际蜜月行
# 3      34980  5  "城市那么大，看不到尽头。在哪里 ? 我能看到吗 ? 就连街道都已经数不清了，找一个女人，盖...
# 4      17071  5  "但是最后.阴影终会消失.崭新的一天即将来临,连太阳都散发更明亮的光芒..这才是让人永生难忘...
# 5      13320  5  "当你心里明白已经没有回头路的时候，该如何重拾旧日的生活？该如何继续生活？有些事情无法弥补，...
# 6      36956  4  "鬼眼娃娃"说过她嚼的流鼻血很美丽，鲜血绽放开的那一瞬，是动人是销魂。阿叔，你被爆头的样子也...
# 7      21366  5  "今天是星期一，新的一周開展了！" 只有他們的家人以及和他們經歷過同一個訓練和戰鬥的人才真正...
# 8      41136  4  "梨子是什么味道的?" \r\n"你不知道吗?"\r\n"我只想知道它在你心里是什么味道的....
# 9      28160  5  "媒体和技术批判理论"|哈贝马斯，法兰克福学派，技术媒介，全景话语监狱，真实或虚假——拟态环...
# 10     37622  5  "那些被层层叠叠的谎言掩藏起来的真相，那些我们明明知道却不愿意承认的事实，那些明知道会痛不欲...
# 11     20362  5  "你以为拍下的东西就会有人看,如此就有人关心这儿的情況?我想不,他们会边看电视边说『天哪,那...
# 12     20662  5  "你以为拍下的东西就会有人看,如此就有人关心这儿的情況?我想不,他们会边看电视边说『天哪,那...
# ...

# %%
for index,row in sheet.iterrows():
    text = row[2]
    if len(text)<20:
        sheet.drop(index)

# %%
sheet.to_excel('douban_comments_clear_round1.xls')
